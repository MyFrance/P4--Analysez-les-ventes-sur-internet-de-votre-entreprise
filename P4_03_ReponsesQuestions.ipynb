# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import scipy.stats as st
import random
import seaborn as sns

# %% [raw]
# ***************************************************************************************************************************
#
#                                                     P4_01_scriptdonnées
#
# ***************************************************************************************************************************

# %% [raw]
# ***************************************************************************************************************************
#
#                                                        NETTOYAGE DES DONNES
#
# ***************************************************************************************************************************

# %% [markdown]
# #             NETTOYAGE DES DONNES

# %% [raw]
# L'obejectif de cette partie d'exercice est de faire le nettoyage des données des dataframes customers, products et transactions.
# Nous allons premièrement faire un nettoyage  dataframe par dataframe. Puis en second, nous allons réunir les trois dataframes pour savoir quel est le comportement de chaque catégorie de client.

# %% [markdown]
# ***************************************************************************************************************************
#
#                                                         Dataframe customers
#
# ***************************************************************************************************************************

# %%
# Nous allons travailler ici avec le fichier csv: customers
customers = pd.read_csv("C:/Users/Utilisateur/projet 4/customers.csv")
customers
# Out:
#      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8618    c_7920   m   1956
# 8619    c_7403   f   1970
# 8620    c_5119   m   1974
# 8621    c_5643   f   1968
# 8622      c_84   f   1982
#
# [8623 rows x 3 columns]

# %% [markdown]
# Ce dataframe est composé de 3 colonnes (client_id, sex, et birth) ainsi que 8623 lignes

# %%
# Nous allons voir ce que contient le dataframe customers en utilisant la fonction describe()
customers.describe()
# Out:
#              birth
# count  8623.000000
# mean   1978.280877
# std      16.919535
# min    1929.000000
# 25%    1966.000000
# 50%    1979.000000
# 75%    1992.000000
# max    2004.000000

# %% [raw]
# En utilisant la fonction describe(), on voit que:
#     - la moyenne des dates de naissance des clients est 1978
#     - la médiane des dates de naissonces est 1979

# %% [markdown]
# # 1- Recherche des valeurs aberrantes dans le Daframe Customers

# %%
#Nous regardons dans client_id comment sont_ils composés
customers.client_id.unique()
# Out:
# array(['c_4410', 'c_7839', 'c_1699', ..., 'c_5119', 'c_5643', 'c_84'],
#       dtype=object)

# %%
message =  "on constate que les id_clients commencent par 'c_{n° séquentiel}'\
Donc on va vérifier que c'est toujours vrai pour éliminer d'eventuelles exceptions"

# %%
# Vérifions que tous les client_id commencent par c_
customers_exceptions = customers[customers["client_id"].str.startswith("c_") ==  False]
customers_exceptions
# Out:
#      client_id sex  birth
# 2735      ct_0   f   2001
# 8494      ct_1   m   2001

# %%
message = " On remarque qu'il y a deux identifiants de client_id qui commencent par ct \
nous allons les identifier et voir à quoi ils correspondent dans la suite de l'analyse en trouvant des\
corrélations avec les autres dataframes"

# %%
#Nous allons faire un masque de customers pour avoir uniquement dans la colonne client_id  les élements commençant 
# que par 'c' car se sont les plus majoritaires 
customers_filter = customers[customers["client_id"].str.startswith("c_")]
customers_filter.head()
# Out:
#   client_id sex  birth
# 0    c_4410   f   1967
# 1    c_7839   f   1975
# 2    c_1699   f   1984
# 3    c_5961   f   1962
# 4    c_5320   m   1943

# %% [markdown]
# # 2- Recherche des valeurs manquantes dans le DataFrame customers

# %% [raw]
# # Pour rechercher les valeurs manquantes, nous allons utiliser la fonction "isna()"

# %%
customers_filter_manquant = pd.isna(customers_filter)
customers_filter_manquant.head()
# Out:
#    client_id    sex  birth
# 0      False  False  False
# 1      False  False  False
# 2      False  False  False
# 3      False  False  False
# 4      False  False  False

# %% [raw]
# Nous allons trier dans le tableau les valeurs qui sonrt à True, car si valeurs manquantes nous renvoi à un True.
# Pour cela on fait un masque pour chaque colonne

# %%
#Masque colonne client_id
customers_filter_manquant[customers_filter_manquant["client_id"] == True]
# Out:
# Empty DataFrame
# Columns: [client_id, sex, birth]
# Index: []

# %%
# Masque colonne sex
customers_filter_manquant[customers_filter_manquant["sex"] == True]
# Out:
# Empty DataFrame
# Columns: [client_id, sex, birth]
# Index: []

# %%
# Masque colonne bith
customers_filter_manquant[customers_filter_manquant["birth"] == True]
# Out:
# Empty DataFrame
# Columns: [client_id, sex, birth]
# Index: []

# %%
Conclusion_valeurs_manquantes = "il n'y pas de valeurs manquantes dans le Dataframe customers"

# %% [markdown]
# # 3- Recherche de doublons dans le DataFrame customers

# %% [markdown]
# Nous allons rechercher les doublons dans le dataframe customers et supprimer toutes les lignes en double avec la fonction drop_duplicates()

# %%
customers_filter.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8618    c_7920   m   1956
# 8619    c_7403   f   1970
# 8620    c_5119   m   1974
# 8621    c_5643   f   1968
# 8622      c_84   f   1982
#
# [8621 rows x 3 columns]>

# %% [raw]
# conclusions_doublons_customers = "au départ on avait 8623 lignes et après le drop_duplicates on a encore 8623 lignes\
# Donc dans le dateframe customers on a pas de doublons car aucune ligne suprimées"

# %% [markdown]
# ### Calcul de l'âge de chaque client

# %%
customers_filter["age"] = 2022 - customers_filter["birth"]
customers_filter.head()
# Out:
# <ipython-input-15-2891c1c7cd23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customers_filter["age"] = 2022 - customers_filter["birth"]
#   client_id sex  birth  age
# 0    c_4410   f   1967   55
# 1    c_7839   f   1975   47
# 2    c_1699   f   1984   38
# 3    c_5961   f   1962   60
# 4    c_5320   m   1943   79

# %% [raw]
#  CONCLUSION NETTOYAGE DE DONNEES DU DATAFRAME CUSTOMERS
#
# 1- Nous avons au total 8623 lignes et 3 colonnes (client_id, sex, birth)
#
# 2- Nous avons deux lignes ct_0  et ct_1	 qui sont différentes des autres au niveau de la colonne client_id. Les autres client_id commencent par c_
#
# 3- Nous n'avons pas trouvé de valeurs manquantes
#
# 4- Nous n'avons pas trouvé des doublons
#
# Nous allons pousuivre notre analyse pour savoir à quoi correspond les identifiants ct_0 et ct_1
#
# PREMIER PROBLEME RENCONTRE: CT_0 ET CT_1

# %% [markdown]
#  **************************************************************************************************************************
#
#                                                      Dataframe Products
#
#  **************************************************************************************************************************

# %% [markdown]
# # 1- Recherche des valeurs aberrantes dans le DataFrame products

# %%
products = pd.read_csv("C:/Users/Utilisateur/projet 4/products.csv")
products.head()
# Out:
#   id_prod  price  categ
# 0  0_1421  19.99      0
# 1  0_1368   5.13      0
# 2   0_731  17.99      0
# 3   1_587   4.99      1
# 4  0_1507   3.99      0

# %% [raw]
# Ce dataframe est composé de 3 colonnes (id_prod, price, et categ) ainsi que 3287 lignes

# %%
# Analyse rapide du dataframe products avec la fonction describe()
products.describe()
# Out:
#              price        categ
# count  3287.000000  3287.000000
# mean     21.856641     0.370246
# std      29.847908     0.615387
# min      -1.000000     0.000000
# 25%       6.990000     0.000000
# 50%      13.060000     0.000000
# 75%      22.990000     1.000000
# max     300.000000     2.000000

# %% [raw]
# En utilisant la fonction describe(), on voit que:
#     - la moyenne des prix d'achat est de 21.86
#     - la médiane sur le prix d'achat est de 13.06
#     - le prix maximum d'achat est à 300.
#     - le prix minimum d'achat est à -1. Ici nous avons une valeur abérrante car on ne peut pas avoir de prix négatif

# %% [markdown]
# # 1- Recherche des valeurs aberrantes du Dataframe products

# %%
# valeurs abérrantes sur les prix
products_price_aberrant = products[products["price"] < 0]
products_price_aberrant
# Out:
#     id_prod  price  categ
# 731     T_0   -1.0      0

# %% [raw]
# message = "Nous avons seulement une valeur négative sur les prix qui correspond à un identifiant T_0 différent des autres\
# nous allons supprimer cette ligne"

# %%
# Notre Dataframe devient: 
product_filter = products[products["price"] >= 0]
product_filter.head()
# Out:
#   id_prod  price  categ
# 0  0_1421  19.99      0
# 1  0_1368   5.13      0
# 2   0_731  17.99      0
# 3   1_587   4.99      1
# 4  0_1507   3.99      0

# %%
# Dans la colonne categ, affichons les différentes categorie du dataframe products
product_filter.categ.unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %% [raw]
# - Nous avons 3 catégories dans ce dataframe [0, 1 et 2]
# - L'identifiant produit "id_prod" commence par le numéro de la  catégorie.
# Et tous les produits commencent par un numero de catégorie qui peut-être soit 0, soit 1, soit 2

# %% [markdown]
# # 2- Recherche des valeurs manquantes dans le dataframe product_filter

# %% [raw]
# Pour rechercher les valeurs manquantes on utilise la fonction pd.isna() de pandas

# %%
product_filter_valeur_manquantes = pd.isna(product_filter)
product_filter_valeur_manquantes.head()
# Out:
#    id_prod  price  categ
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False

# %%
# On fait une recherche en True pour voir s'il y a des valeurs manquantes

product_filter_valeur_manquantes[product_filter_valeur_manquantes["id_prod"] == True]
# Out:
# Empty DataFrame
# Columns: [id_prod, price, categ]
# Index: []

# %%
product_filter_valeur_manquantes[product_filter_valeur_manquantes["price"] == True]
# Out:
# Empty DataFrame
# Columns: [id_prod, price, categ]
# Index: []

# %%
product_filter_valeur_manquantes[product_filter_valeur_manquantes["categ"] == True]
# Out:
# Empty DataFrame
# Columns: [id_prod, price, categ]
# Index: []

# %% [raw]
# Dans le dataframe product_filter on a pas de valeurs manquantes

# %% [markdown]
# # 3- Recherche des doublons dans le DataFrame product_filter

# %% [raw]
# Pour rechercher les doublons on utilise la fonction drop_dublicates

# %%
product_filter = product_filter.drop_duplicates()
product_filter
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3282    2_23  115.99      2
# 3283   0_146   17.14      0
# 3284   0_802   11.22      0
# 3285   1_140   38.56      1
# 3286  0_1920   25.16      0
#
# [3286 rows x 3 columns]

# %% [raw]
# Il n'y a pas de valeur manquante dans le Dataframe product_filter car elle contient autant de lignes que le dataframe d'origine

# %% [raw]
# conclusions sur le dataframe products:
#
#     1- Avec la fonction describe() et le masque sur les prix < 0,  nous avons trouvé une valeur aberrante sur la colonne prix. on a un prix qui est négatif ce qui n'est pas possible.
#
#     2- Nous n'avons pas trouvé de doublons
#
#     3- Nous n'avons pas trouvé de valeurs manquantes
#
#     4- La colonne categ contient 3 catégories qui sont 0, 1 et 2.
#
#     5- La colonne "id_prod qui" represente l'identification du produit commence par le numéro de la catégorie

# %% [markdown]
# ***************************************************************************************************************************
#
#                                                 Dataframe transactions
#
# ***************************************************************************************************************************

# %%
transactions = pd.read_csv ("C:/Users/Utilisateur/projet 4/transactions.csv")
transactions.head()
# Out:
#   id_prod                        date session_id client_id
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242

# %%
# Analyse rapide du dataframe transaction avec la fonction describe()
transactions.describe()
# Out:
#        id_prod                             date session_id client_id
# count   337016                           337016     337016    337016
# unique    3266                           336855     169195      8602
# top      1_369  test_2021-03-01 02:30:02.237413        s_0    c_1609
# freq      1081                               13        200     12855

# %% [raw]
# En utilisant la fonction describe(), on voit que:
#     - le top contient une date commençant par test ce qui est une valeur aberrante.

# %% [markdown]
# # 1- Recherche des valeurs aberrantes dans le DataFrame transactions

# %%
transactions.client_id.unique()
# Out:
# array(['c_4450', 'c_277', 'c_4270', ..., 'c_5139', 'c_4679', 'c_8005'],
#       dtype=object)

# %% [raw]
# En appliquant la fonction .unique() au dataframe transaction à la colonne client_id on remarque qu'ils commence tous par c_{n° séquentiel}
# Donc on va verifier que c'est toujours vrai pour éliminer d'eventuelles exceptions

# %%
transactions_exceptions = transactions[transactions["client_id"].str.startswith("c_") == False]
transactions_exceptions
# Out:
#        id_prod                             date session_id client_id
# 1431       T_0  test_2021-03-01 02:30:02.237420        s_0      ct_1
# 2365       T_0  test_2021-03-01 02:30:02.237446        s_0      ct_1
# 2895       T_0  test_2021-03-01 02:30:02.237414        s_0      ct_1
# 5955       T_0  test_2021-03-01 02:30:02.237441        s_0      ct_0
# 7283       T_0  test_2021-03-01 02:30:02.237434        s_0      ct_1
# ...        ...                              ...        ...       ...
# 332594     T_0  test_2021-03-01 02:30:02.237445        s_0      ct_0
# 332705     T_0  test_2021-03-01 02:30:02.237423        s_0      ct_1
# 332730     T_0  test_2021-03-01 02:30:02.237421        s_0      ct_1
# 333442     T_0  test_2021-03-01 02:30:02.237431        s_0      ct_1
# 335279     T_0  test_2021-03-01 02:30:02.237430        s_0      ct_0
#
# [200 rows x 4 columns]

# %%
transactions_exceptions = transactions[transactions["date"].str.startswith("test_")]
transactions_exceptions
# Out:
#        id_prod                             date session_id client_id
# 1431       T_0  test_2021-03-01 02:30:02.237420        s_0      ct_1
# 2365       T_0  test_2021-03-01 02:30:02.237446        s_0      ct_1
# 2895       T_0  test_2021-03-01 02:30:02.237414        s_0      ct_1
# 5955       T_0  test_2021-03-01 02:30:02.237441        s_0      ct_0
# 7283       T_0  test_2021-03-01 02:30:02.237434        s_0      ct_1
# ...        ...                              ...        ...       ...
# 332594     T_0  test_2021-03-01 02:30:02.237445        s_0      ct_0
# 332705     T_0  test_2021-03-01 02:30:02.237423        s_0      ct_1
# 332730     T_0  test_2021-03-01 02:30:02.237421        s_0      ct_1
# 333442     T_0  test_2021-03-01 02:30:02.237431        s_0      ct_1
# 335279     T_0  test_2021-03-01 02:30:02.237430        s_0      ct_0
#
# [200 rows x 4 columns]

# %% [raw]
# Nous avons donc 200 lignes qui correspondent à des sessions de test notées ct_(N°de categorie).
# Donc on peut conclure que dans le dataframe customers qui a des client_id qui commencent aussi par ct_ sont
# des valeurs abérrantes. Nous allons les éliminer du dataframe transactions et du dataframe products.
#
# PROBLEME 1:
#     Eliminer les client_id qui commencent par ct_ dans les dataframes customers et transactions

# %% [raw]
# On filtre le dataframe Transaction pour ne garder que les les clients_id qui commencent par c_

# %%
transactions_filter = transactions[transactions["client_id"].str.startswith("c_") == True]
transactions_filter.head()
# Out:
#   id_prod                        date session_id client_id
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242

# %% [markdown]
# # 2 - Traitement des valeurs manquantes dans le DataFrame transactions¶

# %% [raw]
# Pour trouver les valeurs manquantes on utilise pd.isna()

# %%
transactions_valeurs_manquantes = pd.isna(transactions_filter)
transactions_valeurs_manquantes.head()
# Out:
#    id_prod   date  session_id  client_id
# 0    False  False       False      False
# 1    False  False       False      False
# 2    False  False       False      False
# 3    False  False       False      False
# 4    False  False       False      False

# %% [raw]
# On verifie que nous avons enlevé toutes les valeurs manquantes en faisant un masque par colonne avec la valeur True

# %%
transactions_valeurs_manquantes[transactions_valeurs_manquantes["id_prod"] == True]
# Out:
# Empty DataFrame
# Columns: [id_prod, date, session_id, client_id]
# Index: []

# %%
transactions_valeurs_manquantes[transactions_valeurs_manquantes["date"] == True]
# Out:
# Empty DataFrame
# Columns: [id_prod, date, session_id, client_id]
# Index: []

# %%
transactions_valeurs_manquantes[transactions_valeurs_manquantes["session_id"] == True]
# Out:
# Empty DataFrame
# Columns: [id_prod, date, session_id, client_id]
# Index: []

# %%
transactions_valeurs_manquantes[transactions_valeurs_manquantes["client_id"] == True]
# Out:
# Empty DataFrame
# Columns: [id_prod, date, session_id, client_id]
# Index: []

# %% [raw]
# Conclusions:
#     il n'y a pas de valeurs manquantes dans le dataframe transaction

# %% [markdown]
# # 3- Recherche des doublons dans le DataFrame transactions

# %% [raw]
# Pour rechercher les doublons on utilise la fonction drop_duplicates

# %%
transactions_filter = transactions_filter.drop_duplicates()
transactions_filter.head()
# Out:
#   id_prod                        date session_id client_id
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242

# %% [raw]
# Il n'y a pas de valeur manquante dans le Dataframe transaction_filter car elle contient autant de lignes que le dataframe d'origine soit 336816 lignes

# %% [raw]
# Conclusions sur dataframe transactions:
#     1- Grâce au dataframe transaction, on peut conclure que ct est une valeur abérrante,
#     utilisé comme client_id pour faire les tests.
#
#     2- il n' ya pas de doublons
#
#     3- il n'ya pas de valeurs manquantes
#
#     4 - Toutes les session de test ont été supprimées (client_id commençant par ct qui est une valeur abérrante)

# %% [markdown]
# ### La date du dataframe transaction n'est pas dans un format approprié , nous allons le mettre au format année_mois, année, jour, et mois

# %%
#Tout d'abord on convertie la date en format pouvant être modifié avec la fonction to_datetime de pandas.
# Pour cela on crée la colonne date_time 
transactions_filter["date_time"] = pd.to_datetime(transactions_filter["date"])

# %%
# On crée une colonne année_mois_jour
transactions_filter["YearMonthDay"] = transactions_filter.date_time.dt.strftime("%Y_%m_%d")

# %%
# On convertie la date aussi en mois et année
transactions_filter["YearMonth"] = transactions_filter.date_time.dt.strftime("%Y_%m")

# %%
# on convertie la date en jour, mois et année séparement
transactions_filter["Year"], transactions_filter["Month"], transactions_filter["Day"] =\
transactions_filter["date_time"].dt.year, transactions_filter["date_time"].dt.month, transactions_filter["date_time"].dt.day 
transactions_filter.head()
# Out:
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10
# 1 2022-02-03 01:55:53.276402   2022_02_03   2022_02  2022      2    3
# 2 2021-09-23 15:13:46.938559   2021_09_23   2021_09  2021      9   23
# 3 2021-10-17 03:27:18.783634   2021_10_17   2021_10  2021     10   17
# 4 2021-07-17 20:34:25.800563   2021_07_17   2021_07  2021      7   17

# %% [raw]
# *****************************************L'analyse commence ici ***********************************************************

# %% [markdown]
# ***************************************************************************************************************************
#
#                                                P4_02_scriptanalyse
#
# ***************************************************************************************************************************

# %% [raw]
# ***************************************************************************************************************************
#
#                                                     ANALYSE
#
# ***************************************************************************************************************************

# %% [markdown]
# ## Nous allons faire la jointure de nos trois dataframes customers, products et transactions pour obtenir un unique dataframe

# %% [raw]
# Jointure entre le dataframe transaction_filter et products_filter
# La condition de jointure est id_prod
# on fait une jointure à gauche

# %%
transaction_product = pd.merge(transactions_filter, product_filter, left_on =["id_prod"], right_on = ["id_prod"], how = "left")
transaction_product.head()
# Out:
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10   4.99
# 1 2022-02-03 01:55:53.276402   2022_02_03   2022_02  2022      2    3  65.75
# 2 2021-09-23 15:13:46.938559   2021_09_23   2021_09  2021      9   23  10.71
# 3 2021-10-17 03:27:18.783634   2021_10_17   2021_10  2021     10   17   4.20
# 4 2021-07-17 20:34:25.800563   2021_07_17   2021_07  2021      7   17   8.99
#
#    categ
# 0    0.0
# 1    2.0
# 2    1.0
# 3    0.0
# 4    0.0

# %% [raw]
# jointure entre transaction_product et customers_filter
# La condition de jointure = client_id
# on fait la jointure à gauche

# %%
analyse_transaction = pd.merge(transaction_product, customers_filter, left_on = ["client_id"], right_on = ["client_id"], how = "left")
analyse_transaction.head()
# Out:
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10   4.99
# 1 2022-02-03 01:55:53.276402   2022_02_03   2022_02  2022      2    3  65.75
# 2 2021-09-23 15:13:46.938559   2021_09_23   2021_09  2021      9   23  10.71
# 3 2021-10-17 03:27:18.783634   2021_10_17   2021_10  2021     10   17   4.20
# 4 2021-07-17 20:34:25.800563   2021_07_17   2021_07  2021      7   17   8.99
#
#    categ sex  birth  age
# 0    0.0   f   1977   45
# 1    2.0   f   2000   22
# 2    1.0   f   1979   43
# 3    0.0   m   1963   59
# ...

# %% [markdown]
# # Analyse des données du dataframe analyse_transaction issue de la jointure des 3 dataframes d'origine

# %% [markdown]
# ### Verifions que durant la jointure nous n'avons pas perdu des données

# %% [markdown]
# Nous allons utiliser la fonction .info() qui nous donne le nombre le lignes non_nulles de chaque colonnes

# %%
analyse_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336816 entries, 0 to 336815
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id_prod       336816 non-null  object
#  1   date          336816 non-null  object
#  2   session_id    336816 non-null  object
#  3   client_id     336816 non-null  object
#  4   date_time     336816 non-null  datetime64[ns]
#  5   YearMonthDay  336816 non-null  object
#  6   YearMonth     336816 non-null  object
#  7   Year          336816 non-null  int64
#  8   Month         336816 non-null  int64
#  9   Day           336816 non-null  int64
#  10  price         336713 non-null  float64
#  11  categ         336713 non-null  float64
#  12  sex           336816 non-null  object
#  13  birth         336816 non-null  int64
#  14  age           336816 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(7)
# memory usage: 32.1+ MB

# %% [raw]
# Nous remarquons que :
#     - Les colonnes id_prod, date, session_id, client_id, sex et birth ont le même nombre de lignes soit 336816.
#     - Les colonnes price et categ quant à elles n'ont que 336713.
# Il manque donc 103 lignes dans les colonnes price et categ

# %% [raw]
# Nous recherchons les lignes qui sont nulles avec la fonction isnull()

# %%
analyse_transaction_isnull_price = analyse_transaction[analyse_transaction["price"].isnull()]
analyse_transaction_isnull_price.head()
# Out:
#       id_prod                        date session_id client_id  \
# 6231   0_2245  2021-06-17 03:03:12.668129    s_49705    c_1533
# 10797  0_2245  2021-06-16 05:53:01.627491    s_49323    c_7954
# 14045  0_2245  2021-11-24 17:35:59.911427   s_124474    c_5120
# 17480  0_2245  2022-02-28 18:08:49.875709   s_172304    c_4964
# 21071  0_2245  2021-03-01 00:09:29.301897        s_3     c_580
#
#                        date_time YearMonthDay YearMonth  Year  Month  Day  \
# 6231  2021-06-17 03:03:12.668129   2021_06_17   2021_06  2021      6   17
# 10797 2021-06-16 05:53:01.627491   2021_06_16   2021_06  2021      6   16
# 14045 2021-11-24 17:35:59.911427   2021_11_24   2021_11  2021     11   24
# 17480 2022-02-28 18:08:49.875709   2022_02_28   2022_02  2022      2   28
# 21071 2021-03-01 00:09:29.301897   2021_03_01   2021_03  2021      3    1
#
#        price  categ sex  birth  age
# 6231     NaN    NaN   m   1972   50
# 10797    NaN    NaN   m   1973   49
# ...

# %% [raw]
# Déterminons le nombre de produits avec des valeurs manquantes.
# Pour cela on .unique() sur la colonne id_prod

# %%
analyse_transaction_isnull_price.id_prod.unique()
# Out:
# array(['0_2245'], dtype=object)

# %% [raw]
# Dans le dataframe analyse_transaction on a qu'un seule produit qui présente des valeurs manquantes c'est le produit 0_2245

# %% [raw]
# Nous retrouvons 103 lignes manquantes qui contiennent des NaN
# Ces 103 lignes correspondent à un seul produit qui 0_2245
#
# Les questions à se poser sont?
# d'où provient ce produit?
#  - du data transaction.
# Pourqoi on a pas retrouvé de correspondance produit dans le dataframe "analyse_transaction"?
#  - Peut_être parce que on l'a rétiré des stocks
#  - le produit a peut-être été perdu lors de la récupération des données.
#
# Pouvons nous supprimer ces lignes sans affecter l'analyse ou bien pouvons nous reconstruire les données?
#
# Nous allons reconstruire les données de cet id_prod =0_2245
#
# 1- Tout d'abord on peut connaître la catégorie de ce produit, car l'id_prod commence par son numéro de catégorie:
#     ici la catégorie est categ = 0
# 2- Nous allons attribuer un prix à ce produit en prenant la moyenne des produits de la catégorie 0 car les données sont
# plus homogènes dans une catégorie .

# %% [markdown]
# # Reconstruction des données du dataframe analyse_transaction

# %% [raw]
# On connait la catégorie de ce produit c'est 0. Avec la fonction replace(np.nan, "valeur qu'on remplace")

# %%
# On remplace les nan de la catégorie 0 par 0
analyse_transaction["categ"] = analyse_transaction["categ"].replace(np.nan, 0)
analyse_transaction.categ.unique()
# Out:
# array([0., 2., 1.])

# %% [markdown]
# Calcul de la moyenne des produit de la categorie 0

# %%
#Pour cela on fait un masque en ne récupérant que les identifiants qui commencent par 0
analyse_transaction_categ_0 = analyse_transaction[analyse_transaction["id_prod"].str.startswith("0_")]
analyse_transaction_categ_0.head()
# Out:
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# 5  0_1085  2021-09-15 05:47:48.215162    s_90139    c_2526
# 6  0_1508  2021-08-29 05:39:01.055455    s_82100    c_5799
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10   4.99
# 3 2021-10-17 03:27:18.783634   2021_10_17   2021_10  2021     10   17   4.20
# 4 2021-07-17 20:34:25.800563   2021_07_17   2021_07  2021      7   17   8.99
# 5 2021-09-15 05:47:48.215162   2021_09_15   2021_09  2021      9   15   3.99
# 6 2021-08-29 05:39:01.055455   2021_08_29   2021_08  2021      8   29   8.03
#
#    categ sex  birth  age
# 0    0.0   f   1977   45
# 3    0.0   m   1963   59
# 4    0.0   f   1980   42
# 5    0.0   f   1982   40
# ...

# %% [raw]
# calcul de la moyenne sur la categorie 0

# %%
analyse_transaction_categ_0.dropna(subset = ["price"], how = "all", inplace = True)
analyse_transaction_moyenne_categ_0 = analyse_transaction_categ_0["price"].mean()
analyse_transaction_moyenne_categ_0
# Out:
# <ipython-input-49-ecb937b6f4bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analyse_transaction_categ_0.dropna(subset = ["price"], how = "all", inplace = True)
# 10.646828235274288

# %% [raw]
# # on remplace les Nan présents dans la colonne price par la moyenne de la catégorie 0 calculée en utilisant la fonction fillna()

# %%
analyse_transaction["price"] = analyse_transaction["price"].fillna(analyse_transaction_moyenne_categ_0)
analyse_transaction.head()
# Out:
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10   4.99
# 1 2022-02-03 01:55:53.276402   2022_02_03   2022_02  2022      2    3  65.75
# 2 2021-09-23 15:13:46.938559   2021_09_23   2021_09  2021      9   23  10.71
# 3 2021-10-17 03:27:18.783634   2021_10_17   2021_10  2021     10   17   4.20
# 4 2021-07-17 20:34:25.800563   2021_07_17   2021_07  2021      7   17   8.99
#
#    categ sex  birth  age
# 0    0.0   f   1977   45
# 1    2.0   f   2000   22
# 2    1.0   f   1979   43
# 3    0.0   m   1963   59
# ...

# %% [raw]
# on verifie que 0_2245 a bien été reconstruit

# %%
produit_0_2245 = analyse_transaction[analyse_transaction["id_prod"] == "0_2245"]
produit_0_2245.head()
# Out:
#       id_prod                        date session_id client_id  \
# 6231   0_2245  2021-06-17 03:03:12.668129    s_49705    c_1533
# 10797  0_2245  2021-06-16 05:53:01.627491    s_49323    c_7954
# 14045  0_2245  2021-11-24 17:35:59.911427   s_124474    c_5120
# 17480  0_2245  2022-02-28 18:08:49.875709   s_172304    c_4964
# 21071  0_2245  2021-03-01 00:09:29.301897        s_3     c_580
#
#                        date_time YearMonthDay YearMonth  Year  Month  Day  \
# 6231  2021-06-17 03:03:12.668129   2021_06_17   2021_06  2021      6   17
# 10797 2021-06-16 05:53:01.627491   2021_06_16   2021_06  2021      6   16
# 14045 2021-11-24 17:35:59.911427   2021_11_24   2021_11  2021     11   24
# 17480 2022-02-28 18:08:49.875709   2022_02_28   2022_02  2022      2   28
# 21071 2021-03-01 00:09:29.301897   2021_03_01   2021_03  2021      3    1
#
#            price  categ sex  birth  age
# 6231   10.646828    0.0   m   1972   50
# 10797  10.646828    0.0   m   1973   49
# ...

# %%
produit_0_2245.price.unique()
# Out:
# array([10.64682824])

# %%
produit_0_2245.categ.unique()
# Out:
# array([0.])

# %% [markdown]
# ## Evolution du Chiffre d'affaire au cours du temps YearMonth

# %% [raw]
# Nous allons grouper les données en faisant la somme des prix par mois

# %%
analyse_transaction_YearMonth_client = analyse_transaction.groupby(by = ["YearMonth", "client_id"]).agg({"price": "sum"})
analyse_transaction_YearMonth_client = analyse_transaction_YearMonth_client.reset_index()
analyse_transaction_YearMonth_client.head()
# Out:
#   YearMonth client_id   price
# 0   2021_03      c_10   14.99
# 1   2021_03    c_1000  160.77
# 2   2021_03    c_1001  357.19
# 3   2021_03    c_1003  133.96
# 4   2021_03    c_1004   63.09

# %% [raw]
# Nous allons trier les dates par ordre croissant

# %%
analyse_transaction_YearMonth_client.sort_values(by = ["YearMonth"]).head()
# Out:
#      YearMonth client_id   price
# 0      2021_03      c_10   14.99
# 3788   2021_03     c_619   40.31
# 3787   2021_03    c_6189  112.77
# 3786   2021_03    c_6188   49.84
# 3785   2021_03    c_6187   44.47

# %% [markdown]
# Nous allons tracer la courbe qui nous montre l'évolution du CA au cours des mois pour les années 2021 et 2022.
# pour cela on fait un groupby par YearMonth

# %%
analyse_transaction_by_YearMonth = analyse_transaction.groupby(by = ["YearMonth"], dropna = True ).agg({"price": "sum"})
analyse_transaction_by_YearMonth = analyse_transaction_by_YearMonth.reset_index()
analyse_transaction_by_YearMonth.head()
# Out:
#   YearMonth          price
# 0   2021_03  479407.851454
# 1   2021_04  473129.775595
# 2   2021_05  489453.124626
# 3   2021_06  481332.467798
# 4   2021_07  480941.247313

# %%
x = analyse_transaction_by_YearMonth["YearMonth"]
y = analyse_transaction_by_YearMonth["price"]
plt.figure(figsize = (12,8))
ax = plt.axes()
ax = ax.set(xlabel = "Dates", ylabel = "Evolution du chiffre d'affaire")
plt.title("ÉVOLUTION DU CHIFFRE D'AFFAIRE AU COURS DU TEMPS")
plt.plot(x, y)
plt.savefig("ÉVOLUTION DU CHIFFRE D'AFFAIRE AU COURS DU TEMPS.png")
plt.show()

# %% [raw]
# On remarque que le Chiffre d'affaire moyen tourne autour de 480 000 sauf au mois d'octobre 2021 où il chute dratiquement au tour de 320 000

# %% [raw]
# Nous allons grouper les données en faisant la somme des prix par client_id pour identifer les plus gros acheteurs

# %%
analyse_transaction_by_Client_id = analyse_transaction.groupby(by = ["client_id", ]).agg({"price": "sum"})
analyse_transaction_by_Client_id = analyse_transaction_by_Client_id.reset_index()
analyse_transaction_by_Client_id.head()
# Out:
#   client_id    price
# 0       c_1   300.65
# 1      c_10   586.18
# 2     c_100   222.87
# 3    c_1000   980.02
# 4    c_1001  1102.45

# %% [raw]
# Nous allons trier les prix par ordre décroissant

# %%
analyse_transaction_by_ascending_price = analyse_transaction_by_Client_id.sort_values(by =["price"], ascending = False)
analyse_transaction_by_ascending_price.head(10)
# Out:
#      client_id          price
# 677     c_1609  162007.340000
# 4388    c_4958  144257.210000
# 6337    c_6714   73218.633656
# 2724    c_3454   54464.213656
# 7715    c_7959    2564.250000
# 7791    c_8026    2548.316828
# 3870    c_4491    2540.530000
# 1268    c_2140    2527.010000
# 8195    c_8392    2515.980000
# 7120    c_7421    2511.980000

# %% [raw]
# Il en ressort que 4 clients sont acheteurs à gros volumes, ce sont :
#     1 - c_1609	valeur d'achat = 162 007
#     2 - c_4958	valeur d'achat = 144 257
#     3 - c_6714	valeur d'achat = 73 218
#     4 - c_3454	valeur d'achat = 54 464

# %%
clients_forte_valeur_achat = analyse_transaction_by_ascending_price.head(4)
clients_forte_valeur_achat
# Out:
#      client_id          price
# 677     c_1609  162007.340000
# 4388    c_4958  144257.210000
# 6337    c_6714   73218.633656
# 2724    c_3454   54464.213656

# %% [raw]
# Nous allons retirer ces 4 gros clients de la base de données analyse_transaction

# %%
analyse_transaction["is_best_4_client"] = (analyse_transaction["client_id"].isin(clients_forte_valeur_achat.client_id))
analyse_transaction.head()
# Out:
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10   4.99
# 1 2022-02-03 01:55:53.276402   2022_02_03   2022_02  2022      2    3  65.75
# 2 2021-09-23 15:13:46.938559   2021_09_23   2021_09  2021      9   23  10.71
# 3 2021-10-17 03:27:18.783634   2021_10_17   2021_10  2021     10   17   4.20
# 4 2021-07-17 20:34:25.800563   2021_07_17   2021_07  2021      7   17   8.99
#
#    categ sex  birth  age  is_best_4_client
# 0    0.0   f   1977   45             False
# 1    2.0   f   2000   22             False
# ...

# %%
analyse_transaction.is_best_4_client.unique()
# Out:
# array([False,  True])

# %% [raw]
# Nous allons ensuite filtrer pour avoir uniquement les clients non professionnels

# %%
transaction_client_ordinaire = analyse_transaction[analyse_transaction.is_best_4_client == False]
transaction_client_ordinaire.head()
# Out:
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10   4.99
# 1 2022-02-03 01:55:53.276402   2022_02_03   2022_02  2022      2    3  65.75
# 2 2021-09-23 15:13:46.938559   2021_09_23   2021_09  2021      9   23  10.71
# 3 2021-10-17 03:27:18.783634   2021_10_17   2021_10  2021     10   17   4.20
# 4 2021-07-17 20:34:25.800563   2021_07_17   2021_07  2021      7   17   8.99
#
#    categ sex  birth  age  is_best_4_client
# 0    0.0   f   1977   45             False
# 1    2.0   f   2000   22             False
# ...

# %%
transaction_client_ordinaire.is_best_4_client.unique()
# Out:
# array([False])

# %% [raw]
# Evolution du Chiffre d'affaire des clients nons professionnels

# %%
transaction_client_ordinaire_curve = transaction_client_ordinaire.groupby(by = ["YearMonth", "categ",]).agg({"price":"sum"})
transaction_client_ordinaire_curve = transaction_client_ordinaire_curve.reset_index()
transaction_client_ordinaire_curve.head()
# Out:
#   YearMonth  categ          price
# 0   2021_03    0.0  180673.971454
# 1   2021_03    1.0  174569.680000
# 2   2021_03    2.0   87791.280000
# 3   2021_04    0.0  191512.505111
# 4   2021_04    1.0  145272.820000

# %% [raw]
# On fait le trie par ordre croissant

# %%
transaction_client_ordinaire_curve.sort_values(by = "YearMonth")
# Out:
#    YearMonth  categ          price
# 0    2021_03    0.0  180673.971454
# 1    2021_03    1.0  174569.680000
# 2    2021_03    2.0   87791.280000
# 3    2021_04    0.0  191512.505111
# 4    2021_04    1.0  145272.820000
# 5    2021_04    2.0   99541.060000
# 6    2021_05    0.0  182363.924626
# 7    2021_05    1.0  155309.630000
# 8    2021_05    2.0  113723.560000
# 9    2021_06    0.0  156640.760969
# 10   2021_06    1.0  177840.330000
# 11   2021_06    2.0  110450.260000
# 12   2021_07    0.0  135459.987313
# 13   2021_07    1.0  176647.610000
# 14   2021_07    2.0  133591.400000
# 16   2021_08    1.0  152886.830000
# 17   2021_08    2.0  133462.390000
# 15   2021_08    0.0  156918.281454
# 18   2021_09    0.0  229212.171939
# 19   2021_09    1.0  177809.680000
# 20   2021_09    2.0   59856.270000
# 21   2021_10    0.0  184850.477798
# 22   2021_10    1.0   31892.010000
# 23   2021_10    2.0   78570.590000
# 26   2021_11    2.0   94519.060000
# 24   2021_11    0.0  144729.778282
# ...

# %% [raw]
# Nous allons tracer la courbe des clients non professionnels

# %%
transaction_client_ordinaire_curve_pivot = transaction_client_ordinaire_curve.pivot_table( values="price", index=["YearMonth"], columns="categ", aggfunc=np.sum)
transaction_client_ordinaire_curve_pivot = transaction_client_ordinaire_curve_pivot.reset_index()
transaction_client_ordinaire_curve_pivot
# Out:
# categ YearMonth            0.0        1.0        2.0
# 0       2021_03  180673.971454  174569.68   87791.28
# 1       2021_04  191512.505111  145272.82   99541.06
# 2       2021_05  182363.924626  155309.63  113723.56
# 3       2021_06  156640.760969  177840.33  110450.26
# 4       2021_07  135459.987313  176647.61  133591.40
# 5       2021_08  156918.281454  152886.83  133462.39
# 6       2021_09  229212.171939  177809.68   59856.27
# 7       2021_10  184850.477798   31892.01   78570.59
# 8       2021_11  144729.778282  235970.11   94519.06
# 9       2021_12  191471.867798  234369.37   58977.09
# 10      2022_01  153554.834141  239849.07   93224.71
# 11      2022_02  171270.485111  199168.20  119774.94

# %%
#df.head()

# %%
# Make a data frame
#df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21), 'y4': np.random.randn(10)+range(6,16), 'y5': np.random.randn(10)+range(4,14)+(0,0,0,0,0,0,0,-3,-8,-6), 'y6': np.random.randn(10)+range(2,12), 'y7': np.random.randn(10)+range(5,15), 'y8': np.random.randn(10)+range(4,14), 'y9': np.random.randn(10)+range(4,14), 'y10': np.random.randn(10)+range(2,12) })

plt.figure(figsize = (25, 12))
# Change the style of plot
plt.style.use('seaborn-darkgrid')
 
# Create a color palette
palette = plt.get_cmap('Set1')
 
# Plot multiple lines
num=0
for column in transaction_client_ordinaire_curve_pivot.drop('YearMonth', axis=1):
    num+=1
    plt.plot(transaction_client_ordinaire_curve_pivot['YearMonth'], transaction_client_ordinaire_curve_pivot[column], marker='', color=palette(num), linewidth=1, alpha=0.9, label=column)

# Add legend
plt.legend(loc=2, ncol=2)
 
# Add titles
plt.title("Evolution du chiffre d'affaire au cours du temps pour chaque catégorie ", loc='left', fontsize=20, fontweight=0, color='orange')
plt.xlabel("Date")
plt.ylabel("Chiffre d'affaire")
plt.plot(fontsize = 25)
plt.savefig("ÉVOLUTION DU CHIFFRE D'AFFAIRE AU COURS DU TEMPS par categ.png")
# Show the graph
plt.show()

# %% [raw]
# On Remarque qu'au mois d'octobre, le CA de la catégorie 1 chute drastiquement, donc on va voir ce qui se passe réellement au mois d'octobre en faisant un graphique par jour

# %% [raw]
# Nous allons déterminer ceux qui a pu se passer au mois d'octobre.

# %% [raw]
# Nous allons rechercher les transactions d'octobre dans le dataframe transaction_client_ordinaire

# %%
transaction_client_ordinaire["is_client_octobre"] = transaction_client_ordinaire["Month"] == 10
transaction_client_ordinaire.head()
# Out:
# <ipython-input-70-6665fa6cc825>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transaction_client_ordinaire["is_client_octobre"] = transaction_client_ordinaire["Month"] == 10
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3  0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10   4.99
# ...

# %% [raw]
# Nous allons ensuite filtrer pour avoir uniquement les transactions du mois d'octobre

# %%
analyse_transaction_octobre = transaction_client_ordinaire[transaction_client_ordinaire.is_client_octobre == True]
analyse_transaction_octobre.head()
# Out:
#    id_prod                        date session_id client_id  \
# 3   0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 10   0_423  2021-10-09 23:50:33.907269   s_102501    c_2225
# 12  0_1368  2021-10-02 10:50:43.188179    s_98886     c_857
# 14  0_1207  2021-10-12 23:22:51.290635   s_103927     c_648
# 17  0_1452  2021-10-15 10:07:12.401758   s_105078    c_6297
#
#                     date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 3  2021-10-17 03:27:18.783634   2021_10_17   2021_10  2021     10   17   4.20
# 10 2021-10-09 23:50:33.907269   2021_10_09   2021_10  2021     10    9   1.99
# 12 2021-10-02 10:50:43.188179   2021_10_02   2021_10  2021     10    2   5.13
# 14 2021-10-12 23:22:51.290635   2021_10_12   2021_10  2021     10   12  16.99
# 17 2021-10-15 10:07:12.401758   2021_10_15   2021_10  2021     10   15  13.77
#
#     categ sex  birth  age  is_best_4_client  is_client_octobre
# 3     0.0   m   1963   59             False               True
# ...

# %%
analyse_transaction_octobre.categ.unique()
# Out:
# array([0., 2., 1.])

# %% [raw]
# Nous allons faire un pivot_table par pour avoir les éléments contenus dans la colonne categ par jour du mois d'octobre

# %%
client_octobre_by_Day = analyse_transaction_octobre.pivot_table(index="Day",columns="categ", values="price", aggfunc=np.sum)
client_octobre_by_Day = client_octobre_by_Day.reset_index()
client_octobre_by_Day
# Out:
# categ  Day          0.0      1.0      2.0
# 0        1  6258.120000  6530.99  2752.09
# 1        2  6450.520000      NaN  1781.00
# 2        3  6231.860000      NaN  1827.13
# 3        4  6187.613656      NaN  2217.94
# 4        5  6181.620000      NaN  2920.56
# 5        6  7014.930000      NaN  1660.50
# 6        7  5932.980000      NaN  1715.08
# 7        8  6552.440000      NaN  2946.05
# 8        9  6080.920000      NaN  2268.30
# 9       10  5911.370000      NaN  2053.54
# 10      11  6570.660000      NaN  2932.21
# 11      12  6321.250000      NaN  1937.27
# 12      13  6242.930000      NaN  2579.83
# 13      14  6036.470000      NaN  2517.68
# 14      15  6133.146828      NaN  2512.41
# 15      16  6222.320000      NaN  3206.01
# 16      17  6007.650000      NaN  3015.77
# 17      18  5795.060000      NaN  2562.99
# 18      19  5397.363656      NaN  2020.38
# 19      20  5425.316828      NaN  2883.13
# 20      21  6104.470000      NaN  2941.01
# ...

# %% [markdown]
# Ici on remarque une perte de donnée entre 02 et le 27 octobre pour la catégorie 1

# %%
client_octobre_by_Day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Day     31 non-null     int64
#  1   0.0     31 non-null     float64
#  2   1.0     5 non-null      float64
#  3   2.0     31 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 1.0 KB

# %% [raw]
# Nous allons tracer la courbe de vente de mois d'octobre

# %%
plt.figure(figsize = (20, 8))
# Change the style of plot
plt.style.use('seaborn-darkgrid')
 
# Create a color palette
palette = plt.get_cmap('Set1')
 
# Plot multiple lines
num=0
for column in client_octobre_by_Day.drop('Day', axis=1):
    num+=1
    plt.plot(client_octobre_by_Day['Day'], client_octobre_by_Day[column], marker='', color=palette(num), linewidth=1, alpha=0.9, label=column)

# Add legend
plt.legend(loc=2, ncol=2)
 
# Add titles
plt.title("Evolution du chiffre d'affaire au mois d'octobre", loc='center', fontsize=25, fontweight=0, color='orange')
plt.xlabel("Octobre")
plt.ylabel("Chiffre d'affaire")
plt.plot(fontsize = 30)
plt.savefig("Evolution du chiffre d'affaire au mois d'octobre")
# Show the graph
plt.show()

# %% [raw]
# Ici on remarque que la catégorie 0 et 2 ont des comportements normaux alors que la catégrorie 1 présente une évolution anormal cela est dû à la perte de données oberservée entre le 2 et le 26 octobre

# %% [raw]
# Nous allons reconstruire ces données de la catégorie 1 et en le remplaçant.

# %%
analyse_transaction_sans_octobre = transaction_client_ordinaire[transaction_client_ordinaire.is_client_octobre == False]
analyse_transaction_sans_octobre.head()
# Out:
#   id_prod                        date session_id client_id  \
# 0  0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1   2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2   1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 4  0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# 5  0_1085  2021-09-15 05:47:48.215162    s_90139    c_2526
#
#                    date_time YearMonthDay YearMonth  Year  Month  Day  price  \
# 0 2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10   4.99
# 1 2022-02-03 01:55:53.276402   2022_02_03   2022_02  2022      2    3  65.75
# 2 2021-09-23 15:13:46.938559   2021_09_23   2021_09  2021      9   23  10.71
# 4 2021-07-17 20:34:25.800563   2021_07_17   2021_07  2021      7   17   8.99
# 5 2021-09-15 05:47:48.215162   2021_09_15   2021_09  2021      9   15   3.99
#
#    categ sex  birth  age  is_best_4_client  is_client_octobre
# 0    0.0   f   1977   45             False              False
# ...

# %%
analyse_transaction_sans_octobre.is_client_octobre.unique()
# Out:
# array([False])

# %%
analyse_transaction_sans_octobre_pivot = analyse_transaction_sans_octobre.pivot_table(index = ["YearMonthDay"], columns = "categ", values = "price", aggfunc = np.sum)
analyse_transaction_sans_octobre_pivot = analyse_transaction_sans_octobre_pivot.reset_index()
analyse_transaction_sans_octobre_pivot
# Out:
# categ YearMonthDay          0.0      1.0      2.0
# 0       2021_03_01  5943.376828  6375.49  3011.45
# 1       2021_03_02  6171.936828  5253.16  2995.04
# 2       2021_03_03  5722.510000  5217.22  2662.30
# 3       2021_03_04  5434.760000  5614.73  2369.15
# 4       2021_03_05  5500.920000  6522.55  3894.66
# ..             ...          ...      ...      ...
# 329     2022_02_24  6669.766828  6304.71  5894.11
# 330     2022_02_25  5984.043656  5919.94  5024.05
# 331     2022_02_26  6673.290000  6925.03  5088.80
# 332     2022_02_27  6991.140000  6196.39  4639.56
# 333     2022_02_28  6264.476828  6555.43  4617.13
#
# [334 rows x 4 columns]

# %%
moyenne = analyse_transaction_sans_octobre_pivot.describe()
moyenne
# Out:
# categ          0.0          1.0          2.0
# count   334.000000   334.000000   334.000000
# mean   5670.085534  6196.686617  3308.119820
# std     983.855150  1203.632377  1003.160354
# min    3706.570000  4029.820000   901.170000
# 25%    4980.587621  5246.690000  2662.325000
# 50%    5579.865242  5893.220000  3258.415000
# 75%    6204.592500  7306.085000  4020.412500
# max    9380.010000  9798.280000  5998.300000

# %% [raw]
# La moyenne de la catégorie de la catégorie 1 pour tous les mois en enlevant le mois d'octobre est de 6196.7
# Nous allons le remplacer dans les données manquantes du mois d'octobre.

# %%
client_octobre_by_Day_reconstruit = client_octobre_by_Day.fillna(6196.7)
client_octobre_by_Day_reconstruit
# Out:
# categ  Day          0.0      1.0      2.0
# 0        1  6258.120000  6530.99  2752.09
# 1        2  6450.520000  6196.70  1781.00
# 2        3  6231.860000  6196.70  1827.13
# 3        4  6187.613656  6196.70  2217.94
# 4        5  6181.620000  6196.70  2920.56
# 5        6  7014.930000  6196.70  1660.50
# 6        7  5932.980000  6196.70  1715.08
# 7        8  6552.440000  6196.70  2946.05
# 8        9  6080.920000  6196.70  2268.30
# 9       10  5911.370000  6196.70  2053.54
# 10      11  6570.660000  6196.70  2932.21
# 11      12  6321.250000  6196.70  1937.27
# 12      13  6242.930000  6196.70  2579.83
# 13      14  6036.470000  6196.70  2517.68
# 14      15  6133.146828  6196.70  2512.41
# 15      16  6222.320000  6196.70  3206.01
# 16      17  6007.650000  6196.70  3015.77
# 17      18  5795.060000  6196.70  2562.99
# 18      19  5397.363656  6196.70  2020.38
# 19      20  5425.316828  6196.70  2883.13
# 20      21  6104.470000  6196.70  2941.01
# ...

# %%
#Calcul de la moyenne des prix au mois d'octobre 
moyenne_octobre = client_octobre_by_Day_reconstruit[1.0].sum()
moyenne_octobre
# Out:
# 193006.2099999999

# %%
# Nous allons injecter cette moyenne dans le mois d'octobre 
transaction_client_ordinaire_pivot = transaction_client_ordinaire.pivot_table(index = "Month", columns = "categ", values = "price", aggfunc = np.sum)
transaction_client_ordinaire_pivot = transaction_client_ordinaire_pivot.reset_index()
transaction_client_ordinaire_pivot
# Out:
# categ  Month            0.0        1.0        2.0
# 0          1  153554.834141  239849.07   93224.71
# 1          2  171270.485111  199168.20  119774.94
# 2          3  180673.971454  174569.68   87791.28
# 3          4  191512.505111  145272.82   99541.06
# 4          5  182363.924626  155309.63  113723.56
# 5          6  156640.760969  177840.33  110450.26
# 6          7  135459.987313  176647.61  133591.40
# 7          8  156918.281454  152886.83  133462.39
# 8          9  229212.171939  177809.68   59856.27
# 9         10  184850.477798   31892.01   78570.59
# 10        11  144729.778282  235970.11   94519.06
# 11        12  191471.867798  234369.37   58977.09

# %%
transaction_client_ordinaire_pivot.columns = ["Month","categ_0", "categ_1", "categ_2"]
transaction_client_ordinaire_pivot
# Out:
#     Month        categ_0    categ_1    categ_2
# 0       1  153554.834141  239849.07   93224.71
# 1       2  171270.485111  199168.20  119774.94
# 2       3  180673.971454  174569.68   87791.28
# 3       4  191512.505111  145272.82   99541.06
# 4       5  182363.924626  155309.63  113723.56
# 5       6  156640.760969  177840.33  110450.26
# 6       7  135459.987313  176647.61  133591.40
# 7       8  156918.281454  152886.83  133462.39
# 8       9  229212.171939  177809.68   59856.27
# 9      10  184850.477798   31892.01   78570.59
# 10     11  144729.778282  235970.11   94519.06
# 11     12  191471.867798  234369.37   58977.09

# %% [raw]
# On remplace la valeur du mois d'octobre dans le tableau par sa valeur estimée

# %%
transaction_client_ordinaire_pivot.iloc[9,2::3] = 193006.2
transaction_client_ordinaire_pivot
# Out:
#     Month        categ_0    categ_1    categ_2
# 0       1  153554.834141  239849.07   93224.71
# 1       2  171270.485111  199168.20  119774.94
# 2       3  180673.971454  174569.68   87791.28
# 3       4  191512.505111  145272.82   99541.06
# 4       5  182363.924626  155309.63  113723.56
# 5       6  156640.760969  177840.33  110450.26
# 6       7  135459.987313  176647.61  133591.40
# 7       8  156918.281454  152886.83  133462.39
# 8       9  229212.171939  177809.68   59856.27
# 9      10  184850.477798  193006.20   78570.59
# 10     11  144729.778282  235970.11   94519.06
# 11     12  191471.867798  234369.37   58977.09

# %% [raw]
# CONCLUSIONS SUR L'ANALYSE DES DONNEES:
#     Nous avons recesser 3 problèmes au cours de notre analyse
#     1 - La présence de lignes test (103 lignes ) dans le dataframe transaction. Nous avons supprimé ces lignes
#
#     2 - La présence dans la colonne client_id égale à ct_0 et ct_1 présent dans le dataframe customers et confirmés dans le dataframe Transaction. Ces client_id correspondent au client_id des personnes qui font les tests sur le site, que nous avons évidemment supprimé
#
#     3 - Dans notre dataframe final analyse_transaction obtenu en joingant le trois datraframes nous avons constaté:
#
#        A -  Un produit dont id_prod = 0_2245 qui n'avait ni prix ni catégorie. Nous avons réussi à reconstruire ce produit car l'id_prod commencant par son numéro de catégorie donc ici 0 et pour le prix nous avons fait la moyenne de tous les prix de la catégorie 0 que nous avons injecté dans la colonne prix pour ce produit.
#
#        B - Nous avons aussi remarqué qu'il y avait deux type de clients: des clients professionnels et les nons professionnels, nous avons enlevé les clients professionnels de notre dataframe pour se concentrer uniquement sur les clients non professionnels pour ce qui permet d'avoir des données sont plus homogènes.
#
#        C - Dans notre Dataframe final analyse_transaction, nous avons aussi constaté, une chute du CA au mois d'octobre,  entre le 01 et le 26 octobre cela est dû au fait que durant cette période, nous avons eu une perte de données pour les produits de la catégorie 1.
#        Nous avons alors reconstruit ces données en faissant la moyenne des prix de la même catégorie pour tous les autres mois et en l'affectant au mois d'octobre

# %% [markdown]
# # INDICATEURS DE TENDANCE CENTRALE ET DE DISPERSION

# %% [markdown]
#  ### Calcul de la moyenne, la médiane et le mode des Clients par catégories

# %% [raw]
# Nous allons travailler dans la suite avec les données en excluant le mois d'octobre.

# %%
transaction_client_ordinaire_group = analyse_transaction_sans_octobre.groupby(by =["YearMonth", "categ"]).agg({"price": "sum"}) 
transaction_client_ordinaire_group = transaction_client_ordinaire_group.reset_index()
transaction_client_ordinaire_group
# Out:
#    YearMonth  categ          price
# 0    2021_03    0.0  180673.971454
# 1    2021_03    1.0  174569.680000
# 2    2021_03    2.0   87791.280000
# 3    2021_04    0.0  191512.505111
# 4    2021_04    1.0  145272.820000
# 5    2021_04    2.0   99541.060000
# 6    2021_05    0.0  182363.924626
# 7    2021_05    1.0  155309.630000
# 8    2021_05    2.0  113723.560000
# 9    2021_06    0.0  156640.760969
# 10   2021_06    1.0  177840.330000
# 11   2021_06    2.0  110450.260000
# 12   2021_07    0.0  135459.987313
# 13   2021_07    1.0  176647.610000
# 14   2021_07    2.0  133591.400000
# 15   2021_08    0.0  156918.281454
# 16   2021_08    1.0  152886.830000
# 17   2021_08    2.0  133462.390000
# 18   2021_09    0.0  229212.171939
# 19   2021_09    1.0  177809.680000
# 20   2021_09    2.0   59856.270000
# 21   2021_11    0.0  144729.778282
# 22   2021_11    1.0  235970.110000
# 23   2021_11    2.0   94519.060000
# 24   2021_12    0.0  191471.867798
# 25   2021_12    1.0  234369.370000
# ...

# %% [markdown]
# ### Calcul de la moyenne, la médiane et le mode par catégorie

# %%
for cat in transaction_client_ordinaire_group["categ"].unique():
    subset = transaction_client_ordinaire_group[transaction_client_ordinaire_group.categ == cat] # création d'un sous échantillone
    print("_"*20) # on met 20 fois le tiret pour séparer chaque valeur
    print("Catégorie:\n" , cat) # on affiche les catégories de transaction_client_non_professionnel
    print("Moyenne:\n", round(subset["price"].mean()))
    print("Médiane:\n", round(subset["price"].median()))
    print("Mode;\n", round(subset["price"].mode()))
# Out:
# ____________________
# Catégorie:
#  0.0
# Moyenne:
#  172164
# Médiane:
#  171270
# Mode;
#  0     135460.0
# 1     144730.0
# 2     153555.0
# 3     156641.0
# 4     156918.0
# 5     171270.0
# 6     180674.0
# 7     182364.0
# 8     191472.0
# 9     191513.0
# 10    229212.0
# dtype: float64
# ____________________
# Catégorie:
#  1.0
# Moyenne:
#  188154
# Médiane:
#  177810
# Mode;
#  0     145273.0
# 1     152887.0
# 2     155310.0
# 3     174570.0
# 4     176648.0
# 5     177810.0
# 6     177840.0
# 7     199168.0
# 8     234369.0
# 9     235970.0
# 10    239849.0
# dtype: float64
# ____________________
# Catégorie:
#  2.0
# Moyenne:
#  100447
# Médiane:
#  99541
# Mode;
#  0      58977.0
# 1      59856.0
# 2      87791.0
# 3      93225.0
# 4      94519.0
# 5      99541.0
# 6     110450.0
# 7     113724.0
# 8     119775.0
# 9     133462.0
# 10    133591.0
# dtype: float64

# %% [raw]
# Catégorie 0:
#     moyenne = 173 222
#     médiane = 175 972
#     mode(0) = 135 460
#
# Catégorie 1:
#     moyenne = 184248
#     médiane = 177810
#     mode(0) = 145273
#
# Catégorie 2:
#     moyenne = 98 624
#     médiane = 97 030
#     mode(0) = 58 977

# %%
analyse_transaction_sans_octobre
# Out:
#        id_prod                        date session_id client_id  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# 5       0_1085  2021-09-15 05:47:48.215162    s_90139    c_2526
# ...        ...                         ...        ...       ...
# 336808   1_413  2022-01-10 13:47:23.973957   s_147795    c_3706
# 336809  0_1475  2021-07-22 13:47:39.400914    s_65686    c_5607
# 336810   1_498  2022-02-03 01:39:15.793010   s_159138    c_1857
# 336812   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 336813  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
#
#                         date_time YearMonthDay YearMonth  Year  Month  Day  \
# 0      2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10
# ...

# %% [markdown]
# # ANALYSE DE CONCENTRATION VIA UNE COURBE DE LORENZ

# %%
analyse_transaction_sans_octobre_lorenz_id_prod= analyse_transaction_sans_octobre.groupby(by ="id_prod" ).agg({"price": sum})
analyse_transaction_sans_octobre_lorenz_id_prod = analyse_transaction_sans_octobre_lorenz_id_prod.reset_index()
analyse_transaction_sans_octobre_lorenz_id_prod
# Out:
#      id_prod     price
# 0        0_0   1950.00
# 1        0_1   2406.81
# 2       0_10    125.65
# 3      0_100     41.20
# 4     0_1000   1238.04
# ...      ...       ...
# 3252    2_95    296.97
# 3253    2_96  11546.31
# 3254    2_97    643.96
# 3255    2_98    149.74
# 3256    2_99    169.98
#
# [3257 rows x 2 columns]

# %%
prix_achat = analyse_transaction_sans_octobre_lorenz_id_prod[analyse_transaction_sans_octobre_lorenz_id_prod['price'] > 0] # sous échantillon = prix_achat
prix = prix_achat['price'].values
lorenz_id_prod = np.cumsum(np.sort(prix)) / prix.sum() # on tri par ordre croissant 
lorenz_id_prod = np.append([0],lorenz_id_prod) # La courbe de Lorenz commence à 0
plt.figure(figsize = (12, 8))
plt.plot(np.linspace(0,1,len(lorenz_id_prod)),lorenz_id_prod,drawstyle='steps-post')

ax = plt.axes()
plt.title("Courbe de Lorenz: Repartion de CA pour les produits ", fontsize = 15, color = "blue")
## line plot of equality
ax.plot([0,1], [0,1], color='k')
ax = ax.set(xlabel='Repartition des produits', ylabel='CA cumulés en %')
plt.rcParams.update({'font.size': 30})
plt.savefig("Courbe de lorenz Repartion de CA pour les produits")
plt.show()
# Out:
# <ipython-input-138-23b378a40c3d>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %% [raw]
# 10% des produits rapportent 50% du Chiffre d'affaire

# %% [markdown]
# ## Indice de Gini

# %%
air_sous_courbe= lorenz_id_prod[:-1].sum()/len(lorenz_id_prod)
s = 0.5 - air_sous_courbe
gini = 2 * s
gini
# Out:
# 0.7403660548426614

# %%
analyse_transaction_sans_octobre_lorenz_client_id= analyse_transaction_sans_octobre.groupby(by ="client_id" ).agg({"price": sum})
analyse_transaction_sans_octobre_lorenz_client_id = analyse_transaction_sans_octobre_lorenz_client_id.reset_index()
analyse_transaction_sans_octobre_lorenz_client_id
# Out:
#      client_id    price
# 0          c_1   292.66
# 1         c_10   586.18
# 2        c_100   222.87
# 3       c_1000   928.05
# 4       c_1001  1009.67
# ...        ...      ...
# 8589     c_995   119.08
# 8590     c_996   725.61
# 8591     c_997   514.90
# 8592     c_998  1527.69
# 8593     c_999   285.03
#
# [8594 rows x 2 columns]

# %%
prix_achat = analyse_transaction_sans_octobre_lorenz_client_id[analyse_transaction_sans_octobre_lorenz_client_id['price'] > 0] # sous échantillon = prix_achat
prix = prix_achat['price'].values
lorenz = np.cumsum(np.sort(prix)) / prix.sum() # on tri par ordre croissant 
lorenz = np.append([0],lorenz) # La courbe de Lorenz commence à 0
plt.figure(figsize = (12, 8))
plt.plot(np.linspace(0,1,len(lorenz)),lorenz,drawstyle='steps-post')

ax = plt.axes()
plt.title("Courbe de lorenz: Repartion des achats pour les clients", fontsize = 15 , color = "blue") 
## line plot of equality
ax.plot([0,1], [0,1], color='k')
ax = ax.set(xlabel='Repartition des clients', ylabel='CA cumulés en %')
plt.rcParams.update({'font.size':15})
plt.show()
plt.savefig("Courbe de lorenz Repartion des achats pour les clients.png")
# Out:
# <ipython-input-130-193b2ec97e02>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %% [raw]
# 30% des clients réalisent 50% de Chiffre d'affaire

# %%
air_sous_courbe= lorenz[:-1].sum()/len(lorenz)
s = 0.5 - air_sous_courbe
gini = 2 * s
gini
# Out:
# 0.3960481630386212

# %% [raw]
# 30 % des clients réalisent 50 % de CA
# Reapartition homogène

# %% [markdown]
# # REPRÉSENTATIONS GRAPHIQUES

# %% [markdown]
# ### HISTOGRAMME

# %% [markdown]
# ### Représentation du chiffre d'affaire par mois

# %%
analyse_transaction_sans_octobre_histo= analyse_transaction_sans_octobre.groupby(by ="YearMonth" ).agg({"price": sum})
analyse_transaction_sans_octobre_histo = analyse_transaction_sans_octobre_histo.reset_index()
analyse_transaction_sans_octobre_histo
# Out:
#    YearMonth          price
# 0    2021_03  443034.931454
# 1    2021_04  436326.385111
# 2    2021_05  451397.114626
# 3    2021_06  444931.350969
# 4    2021_07  445698.997313
# 5    2021_08  443267.501454
# 6    2021_09  466878.121939
# 7    2021_11  475218.948282
# 8    2021_12  484818.327798
# 9    2022_01  486628.614141
# 10   2022_02  490213.625111

# %%
x = analyse_transaction_sans_octobre_histo["YearMonth"]
y= analyse_transaction_sans_octobre_histo["price"]
plt.figure(figsize = (35,20))
plt.bar(x,y,align='center') # A bar chart
plt.xlabel('Date')
plt.ylabel("Chiffre d'affaire")
plt.title("Evolution du chiffre d'affaire par mois", fontsize =50, color = "blue")
plt.savefig("Evolution du chiffre d'affaire par mois")
plt.show()

# %% [raw]
# Ici on voit que le chiffre d'affaire est pratiquement le même au cours des mois

# %% [markdown]
# ### REPRÉSENTATION AVEC DES BOÎTES À MOUSTACHES

# %%
analyse_transaction_sans_octobre
# Out:
#        id_prod                        date session_id client_id  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# 5       0_1085  2021-09-15 05:47:48.215162    s_90139    c_2526
# ...        ...                         ...        ...       ...
# 336808   1_413  2022-01-10 13:47:23.973957   s_147795    c_3706
# 336809  0_1475  2021-07-22 13:47:39.400914    s_65686    c_5607
# 336810   1_498  2022-02-03 01:39:15.793010   s_159138    c_1857
# 336812   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 336813  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
#
#                         date_time YearMonthDay YearMonth  Year  Month  Day  \
# 0      2021-04-10 18:37:28.723910   2021_04_10   2021_04  2021      4   10
# ...

# %%
analyse_transaction_sans_octobre_categ_price = analyse_transaction_sans_octobre.groupby(by = ["YearMonth","categ"]).agg({"price": "sum"})
analyse_transaction_sans_octobre_categ_price = analyse_transaction_sans_octobre_categ_price.reset_index()
analyse_transaction_sans_octobre_categ_price
# Out:
#    YearMonth  categ          price
# 0    2021_03    0.0  180673.971454
# 1    2021_03    1.0  174569.680000
# 2    2021_03    2.0   87791.280000
# 3    2021_04    0.0  191512.505111
# 4    2021_04    1.0  145272.820000
# 5    2021_04    2.0   99541.060000
# 6    2021_05    0.0  182363.924626
# 7    2021_05    1.0  155309.630000
# 8    2021_05    2.0  113723.560000
# 9    2021_06    0.0  156640.760969
# 10   2021_06    1.0  177840.330000
# 11   2021_06    2.0  110450.260000
# 12   2021_07    0.0  135459.987313
# 13   2021_07    1.0  176647.610000
# 14   2021_07    2.0  133591.400000
# 15   2021_08    0.0  156918.281454
# 16   2021_08    1.0  152886.830000
# 17   2021_08    2.0  133462.390000
# 18   2021_09    0.0  229212.171939
# 19   2021_09    1.0  177809.680000
# 20   2021_09    2.0   59856.270000
# 21   2021_11    0.0  144729.778282
# 22   2021_11    1.0  235970.110000
# 23   2021_11    2.0   94519.060000
# 24   2021_12    0.0  191471.867798
# 25   2021_12    1.0  234369.370000
# ...

# %%
x = "categ"   # variable qualitative
y = "price"   # variable quantitative
sous_echantillon = analyse_transaction_sans_octobre_categ_price[analyse_transaction_sans_octobre_categ_price["price"]> 0]
sns.set_palette(sns.color_palette("colorblind",3)) # changement de la palette graphique
modalite = sous_echantillon[x].unique()
groupe = []
fig = plt.figure(figsize=(30,15))
ax = plt.axes()
plt.title("Chiffre d'affaire réalisé dans chaque catégorie par mois") 

ax = ax.set(xlabel="Chiffre d'affaire", ylabel='Catégories')

for m in modalite:
    groupe.append(sous_echantillon[sous_echantillon[x] == m][y])
medianprops = {"color": "black"}
meanprops = {"marker": "o", "markeredgecolor": "black", "markerfacecolor": "firebrick"}
plt.boxplot(groupe, labels = modalite, showfliers = False, medianprops = medianprops, 
           vert = False, patch_artist = True, showmeans = True, meanprops = meanprops)
plt.savefig("CA par categ")
plt.show()

# %% [raw]
# Conclusions:
#     - Les prix les plus bas sont ceux des categories 2 et 0
#     - les prix les plus élevés sont ceux de la catégorie 1
#     - C'est la boite à moustache de la catégorie 1 qui est la plus à droite,
#      cela nous indique que c'est dans la catégorie 1 que nous avons le CA le plus élevés
#     - On peut aussi dire que les prix le CA moins élevés est celui de la catégorie 2.
#     - On remarque aussi que c'est dans la catégorie 2 qu'on a la boite à moustache la plus étroite,
#     c'est-à- l'écart intercartile le plus faible cela veut dire que les prix sont plus homogènes dans la catégorie 2.
#     - On peut aussi affirmer que c'est dans la catégorie 1 que nous avons les prix les moins homogènes.
#     - On remarque aussi que le 4ème quartile de la catégorie 2 est inférieur aux premiers quartiles des catégories 0 et 1
#     cela signifie que 100% des CA mensuel de cette catégorie sont les plus bas à comparer avec ceux des catégorie 0 et 1.

# %% [markdown]
# ### Répartition du chiffre d'affaire par catégorie

# %%
analyse_transaction_sans_octobre_categ_price_pie = analyse_transaction_sans_octobre.groupby(by = ["categ"]).agg({"price": "sum"})
analyse_transaction_sans_octobre_categ_price_pie = analyse_transaction_sans_octobre_categ_price_pie.reset_index()
analyse_transaction_sans_octobre_categ_price_pie
# Out:
#    categ         price
# 0    0.0  1.893809e+06
# 1    1.0  2.069693e+06
# 2    2.0  1.104912e+06

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
plt.figure(figsize =( 12,8))
labels = "Categ_0", "Categ_1", "Categ_2"
sizes = [1.893809e+06, 2.069693e+06, 1.104912e+06]
fig1, ax1 = plt.subplots()
plt.fontsize = 1
ax1.pie(sizes,labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title(" Répartition du chiffre d'affaire par catégorie", fontsize = 15, color = "blue")
plt.savefig("Répartition du CA par categ.png")
plt.show()

# %% [markdown]
# ### REPRÉSENTATION DE SÉRIE TEMPORELLE

# %%
analyse_transaction_sans_octobre_categ_price_pivot = analyse_transaction_sans_octobre_categ_price.pivot_table(index = "YearMonth", columns = "categ", values = "price")
analyse_transaction_sans_octobre_categ_price_pivot = analyse_transaction_sans_octobre_categ_price_pivot.reset_index()
analyse_transaction_sans_octobre_categ_price_pivot
# Out:
# categ YearMonth            0.0        1.0        2.0
# 0       2021_03  180673.971454  174569.68   87791.28
# 1       2021_04  191512.505111  145272.82   99541.06
# 2       2021_05  182363.924626  155309.63  113723.56
# 3       2021_06  156640.760969  177840.33  110450.26
# 4       2021_07  135459.987313  176647.61  133591.40
# 5       2021_08  156918.281454  152886.83  133462.39
# 6       2021_09  229212.171939  177809.68   59856.27
# 7       2021_11  144729.778282  235970.11   94519.06
# 8       2021_12  191471.867798  234369.37   58977.09
# 9       2022_01  153554.834141  239849.07   93224.71
# 10      2022_02  171270.485111  199168.20  119774.94

# %%
plt.figure(figsize = (30, 15))
# Change the style of plot
plt.style.use('seaborn-darkgrid')
 
# Create a color palette
palette = plt.get_cmap('Set1')
 
# Plot multiple lines
num=0
for column in analyse_transaction_sans_octobre_categ_price_pivot.drop('YearMonth', axis=1):
    num+=1
    plt.plot(analyse_transaction_sans_octobre_categ_price_pivot['YearMonth'], analyse_transaction_sans_octobre_categ_price_pivot[column], marker='', color=palette(num), linewidth=1, alpha=0.9, label=column)

# Add legend
plt.legend(loc=2, ncol=2)
 
# Add titles
plt.title("Evolution du chiffre d'affaire sans le mois d'octobre", loc='center', fontsize=40, fontweight=0, color='blue')
plt.xlabel("Mois", fontsize = 30)
plt.ylabel("Chiffre d'affaire", fontsize = 30)
plt.plot(fontsize = 15)
plt.savefig("chiffre d'affaire sans octobre")
# Show the graph
plt.show()

# %% [raw]
# En catégorie 0  le mois où le chiffre d'affaire à atteint son point le plus haut est le mois de septembre. Le CA croit à partir de juillet jusqu'en septembre.
#
# Pour la catégorie 1,le mois avec le CA le plus haut est de novembre à janvier. on observe une croissance de CA à partir du mois d'août jusqu'à janvier.
#
# Les produits de la catégorie 2 ont un chiffre d'affaire moins élevé que en catégorie 0 et 1. toutefois on observe une croissance à partir de juin qui se stabilise entre juillet et août avant de chuter au mois de septembre; au mois de décembre le CA repart à la hausse.

# %% [markdown]
# # Analyses bivariées

# %% [markdown]
# ### 1 - Analyse bivariée entre le sexe des clients et le montant dépensé

# %%
transaction_client_sex = analyse_transaction_sans_octobre.groupby(by = ["sex", "YearMonth"]).agg({"price": "sum"})
transaction_client_sex = transaction_client_sex.reset_index()
transaction_client_sex
# Out:
#    sex YearMonth          price
# 0    f   2021_03  228877.674141
# 1    f   2021_04  229415.617798
# 2    f   2021_05  237872.557798
# 3    f   2021_06  229384.010485
# 4    f   2021_07  229676.073656
# 5    f   2021_08  230349.567313
# 6    f   2021_09  239704.834626
# 7    f   2021_11  247916.517313
# 8    f   2021_12  251943.667313
# 9    f   2022_01  256915.660485
# 10   f   2022_02  253555.150969
# 11   m   2021_03  214157.257313
# 12   m   2021_04  206910.767313
# 13   m   2021_05  213524.556828
# 14   m   2021_06  215547.340485
# 15   m   2021_07  216022.923656
# 16   m   2021_08  212917.934141
# 17   m   2021_09  227173.287313
# 18   m   2021_11  227302.430969
# 19   m   2021_12  232874.660485
# 20   m   2022_01  229712.953656
# 21   m   2022_02  236658.474141

# %%
plt.figure(figsize = (12, 8))
sns.boxplot( x=transaction_client_sex["price"], y=transaction_client_sex["sex"] )
medianprops = {"color": "black"}
plt.title("Analyse bivariée entre le sexe des clients et le montant dépensé", color = "blue")
meanprops = {"marker": "o", "markeredgecolor": "black", "markerfacecolor": "firebrick"}
plt.savefig("analyse entre le sex et le montant dépensé")

# %% [raw]
# On voit que les femmes achètent plus que les hommes

# %% [markdown]
# ### 1 - Analyse bivariée entre l'âge des clients et la catégorie (une variable quantitative et une variable qualitative)¶

# %%
plt.figure(figsize = (12, 8))
plt.title("Analyse bivariée entre l'âge des clients et la catégorie", color = "blue")
sns.boxplot( x=analyse_transaction_sans_octobre["categ"], y=analyse_transaction_sans_octobre["age"], showfliers = False )
plt.savefig("Représentation de l'âge en fonction des catégories")

# %% [raw]
# Dans ces trois boites, on voit que les données les plus homogènes se trouvent dans la catégorie 2 car le corps est plus resseré et les données moins homogènes sont dans la catégorie 1.
# La tranche d'age pour la catégorie 2 est très faible par rapport aux deux autres catégories car son 3 quartile est inférieur aux premier quartile des catégories 0 et 1
# Les clients de tout age achètent les produits de la catégorie 1.
#
# En categorie 0:
#     les clients qui achètent vont de 18 à 65 ans
#     50% des clients qui achètent ont entre 35 et 47 ans
#     25%  ont entre 18 et 35 ans
#     25% entre 47 et 65 ans (3 ème quartile)
#     La médiane est est située autour de 43 ans
#
# En categorie 1:
#     les clients qui achètent vont de 18 à 93 ans
#     50% des clients qui achètent ont entre 35 et 60 ans
#     25%  ont entre 18 et 35 ans
#     25% entre 60 et 93 ans (3 ème quartile)
#     La médiane est est située autour de 47 ans
#
# En catégorie 2:
#     de 18 à 40 ans.
#     50% des clients qui achètent ont entre 20 et 30 ans
#     25%  ont entre 18 et 20 ans
#     25% entre 20 et 33 ans (3 ème quartile)
#     La médiane est est située autour de 47 ans

# %% [markdown]
# ***************************************************************************************************************************
#
#                                                 P4_03_ReponsesQuestions
#
# ***************************************************************************************************************************

# %% [markdown]
# ###  1 - Existe t-il une corrélation entre l'âge des clients et la catégorie des produits achetés?
# Calcul de ANOVA

# %%
transaction_client_sex_categ = analyse_transaction_sans_octobre.groupby(by = ["sex", "categ","YearMonth", "age"]).agg({"price": "sum"})
transaction_client_sex_categ = transaction_client_sex_categ.reset_index()
transaction_client_sex_categ
# Out:
#      sex  categ YearMonth  age   price
# 0      f    0.0   2021_03   18  885.45
# 1      f    0.0   2021_03   19   83.88
# 2      f    0.0   2021_03   20  111.18
# 3      f    0.0   2021_03   21  381.18
# 4      f    0.0   2021_03   22  317.04
# ...   ..    ...       ...  ...     ...
# 4254   m    2.0   2022_02   66  113.99
# 4255   m    2.0   2022_02   67   60.96
# 4256   m    2.0   2022_02   68  162.87
# 4257   m    2.0   2022_02   77  102.82
# 4258   m    2.0   2022_02   80  114.01
#
# [4259 rows x 5 columns]

# %%
transaction_client_sex_categ_pivot = transaction_client_sex_categ.pivot_table( values="price", index=["YearMonth", "sex"], columns=["categ"], aggfunc=np.sum)
transaction_client_sex_categ_pivot = transaction_client_sex_categ_pivot.reset_index()
transaction_client_sex_categ_pivot.head(2)
# Out:
# categ YearMonth sex           0.0       1.0       2.0
# 0       2021_03   f  93297.114141  91074.13  44506.43
# 1       2021_03   m  87376.857313  83495.55  43284.85

# %%
X = "categ" # variable qualitative
Y = "age" # variable quantitative

sous_echantillon = transaction_client_sex_categ[transaction_client_sex_categ["age"] > 0]

def eta_squared(x,y):
    moyenne_y = y.mean()
    classes = []
    for classe in x.unique():
        yi_classe = y[x==classe]
        classes.append({'ni': len(yi_classe),
                        'moyenne_classe': yi_classe.mean()})
    SCT = sum([(yj-moyenne_y)**2 for yj in y])
    SCE = sum([c['ni']*(c['moyenne_classe']-moyenne_y)**2 for c in classes])
    return SCE/SCT
    
eta_squared(sous_echantillon[X],sous_echantillon[Y])
# Out:
# 0.03555228631472819

# %% [raw]
# eta^2 = 0.036
# Il n'y a pas de corrélation entre l'âge des clients et la catégorie des produits
# pas correlation linéaire mais on bien une une corrélation

# %% [markdown]
# ### 2. Nous voulons savoir s'il ya une corrélation entre l'âge et le montant total d'achats par client

# %%
transaction_client_id = analyse_transaction_sans_octobre.groupby(by = ["Month","client_id", "age",]).agg({"price": "sum"})
transaction_client_id = transaction_client_id.reset_index()
transaction_client_id
# Out:
#        Month client_id  age   price
# 0          1    c_1000   56   62.97
# 1          1    c_1003   40   38.42
# 2          1    c_1004   49   40.24
# 3          1    c_1005   81   85.63
# 4          1    c_1006   43  168.10
# ...      ...       ...  ...     ...
# 62891     12     c_990   38  179.91
# 62892     12     c_992   45   29.98
# 62893     12     c_996   52  111.62
# 62894     12     c_998   21  123.15
# 62895     12     c_999   58    4.99
#
# [62896 rows x 4 columns]

# %%
transaction_client_id_sort =transaction_client_id.sort_values(by ="age")
transaction_client_id_sort
# Out:
#        Month client_id  age   price
# 37268      7    c_5278   18  449.50
# 28047      5    c_8112   18   68.99
# 6436       2     c_184   18   62.92
# 60613     12    c_5749   18   53.84
# 6441       2     c_185   18  194.78
# ...      ...       ...  ...     ...
# 50869      9    c_8362   93   21.19
# 3503       1     c_577   93   44.72
# 60260     12    c_5302   93   21.09
# 33886      6    c_8362   93   36.98
# 8957       2    c_5302   93    5.83
#
# [62896 rows x 4 columns]

# %%
plt.figure(figsize = (12,8))
x = transaction_client_id_sort["age"]
y = transaction_client_id_sort["price"]

plt.plot(x, y,'o',alpha=0.5, color = 'pink')
plt.xlabel("Âge")
plt.ylabel("chiffre d'affaire ")
plt.title("Corrélation entre l'âge et le montant total d'achats par client", color = "blue")
plt.savefig("corrélation entre l'age et le montant total d'achats")
plt.show()

# %% [raw]
# Ici on voit que les clients qui ont un panier moyen élevé sont ceux de la tranche 20 à 30 ans.
# plus l'âge augmente plus le prix diminue. à Confirmer avec le coeficient de peason

# %% [markdown]
# ### Calcul du coefficient de corrélation linéaire en calculant le coéfficient de pearson

# %%
print(st.pearsonr(transaction_client_id_sort["age"],transaction_client_id_sort["price"])[0])
# Out:
# -0.24972587495965634

# %% [raw]
# Le coéfficient de Pearson est de -0.255 (corrélation négative) signifiant que lorsque l'âge du client augmente, le prix diminue.Les clients les plus âgés achètent des produits pas chers
# Il y a donc corrélation entre le prix et l'âge

# %% [markdown]
# ### 3. Y a-t-il une corrélation entre le sexe des clients et les catégories de produits achetés ?

# %% [raw]
# Tableau de contingence entre le sexe des clients et la catégorie des produits

# %%
X = "categ"
Y = "sex"

c = analyse_transaction_sans_octobre[[X,Y]].pivot_table(index=X,columns=Y,aggfunc=len)
cont = c.copy()

tx = analyse_transaction_sans_octobre[X].value_counts()
ty = analyse_transaction_sans_octobre[Y].value_counts()

cont.loc[:,"Total"] = tx
cont.loc["total",:] = ty
cont.loc["total","Total"] = len(analyse_transaction_sans_octobre)
cont
# Out:
# sex           f         m     Total
# categ
# 0.0     92331.0   85525.0  177856.0
# 1.0     52993.0   48061.0  101054.0
# 2.0      7575.0    7123.0   14698.0
# total  152899.0  140709.0  293608.0

# %%
tx = pd.DataFrame(tx)
ty = pd.DataFrame(ty)
tx.columns = ["foo"]
ty.columns = ["foo"]
n = len(analyse_transaction_sans_octobre)
indep = tx.dot(ty.T) / n

c = c.fillna(0) # on remplace les valeurs nulles par des 0
mesure = (c-indep)**2/indep
xi_n = mesure.sum().sum()
sns.heatmap(mesure/xi_n,annot=c)
plt.title("Corrélation entre le sexe des clients et les catégories de produits achetés",fontsize = 15,  color = "blue")
plt.savefig("carte thermique" )
plt.show()

# %% [raw]
# En catégorie 2 on voit que les femmes et les hommes ont un même comportement d'achat.
# En catégrie 1 les femmes achètent plus que les hommes
# En catégorie 0 les femmes achètent plus que les hommes
#
# Calcul du chi2

# %%
tx = pd.DataFrame(tx)
ty = pd.DataFrame(ty)
tx.columns = ["foo"]
ty.columns = ["foo"]
n = len(analyse_transaction_sans_octobre)
indep = tx.dot(ty.T) / n

c = c.fillna(0) # on remplace les valeurs nulles par des 0
mesure = (c-indep)**2/indep
xi_n = mesure.sum().sum()
xi_n
# Out:
# 8.965632630745457

# %% [raw]
# Le chi_2 est de 8.96, Il n'y a pas de corrélation entre le sexe et la catégorie

# %% [markdown]
# ### 4. Corrélation entre l'âge des clients et la fréquence d'achat

# %% [markdown]
# ### Calcul de la fréquence d’achat par mois par exemple

# %%
analyse_transaction_sans_octobre["nb_articles_YearMonth"] = 1
analyse_transaction_sans_octobre
# Out:
# <ipython-input-116-093f7183619c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analyse_transaction_sans_octobre["nb_articles_YearMonth"] = 1
#        id_prod                        date session_id client_id  \
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# 5       0_1085  2021-09-15 05:47:48.215162    s_90139    c_2526
# ...        ...                         ...        ...       ...
# 336808   1_413  2022-01-10 13:47:23.973957   s_147795    c_3706
# 336809  0_1475  2021-07-22 13:47:39.400914    s_65686    c_5607
# ...

# %%
#On va faire un groupby par client_id
# Nombre de transaction par mois par âge
transaction_client_YearMonth_session_id = analyse_transaction_sans_octobre.groupby(by =["session_id", "YearMonth", "age"]).agg({"nb_articles_YearMonth": "sum", "price": "sum"})
transaction_client_YearMonth_session_id = transaction_client_YearMonth_session_id.reset_index()
transaction_client_YearMonth_session_id
# Out:
#        session_id YearMonth  age  nb_articles_YearMonth   price
# 0             s_1   2021_03   55                      1   11.99
# 1            s_10   2021_03   52                      1   26.99
# 2           s_100   2021_03   44                      2   33.72
# 3          s_1000   2021_03   33                      4   39.22
# 4         s_10000   2021_03   33                      3   41.49
# ...           ...       ...  ...                    ...     ...
# 147080     s_9995   2021_03   48                      2   38.00
# 147081     s_9996   2021_03   18                      8  129.42
# 147082     s_9997   2021_03   64                      1   11.99
# 147083     s_9998   2021_03   32                      1    7.99
# 147084     s_9999   2021_03   38                      3   34.96
#
# [147085 rows x 5 columns]

# %%
transaction_client_YearMonth_session_id["frequence_achat_mensuel"] = 1
transaction_client_YearMonth_session_id
# Out:
#        session_id YearMonth  age  nb_articles_YearMonth   price  \
# 0             s_1   2021_03   55                      1   11.99
# 1            s_10   2021_03   52                      1   26.99
# 2           s_100   2021_03   44                      2   33.72
# 3          s_1000   2021_03   33                      4   39.22
# 4         s_10000   2021_03   33                      3   41.49
# ...           ...       ...  ...                    ...     ...
# 147080     s_9995   2021_03   48                      2   38.00
# 147081     s_9996   2021_03   18                      8  129.42
# 147082     s_9997   2021_03   64                      1   11.99
# 147083     s_9998   2021_03   32                      1    7.99
# 147084     s_9999   2021_03   38                      3   34.96
#
#         frequence_achat_mensuel
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# ...

# %%
#On va faire un groupby par client_id
# Nombre de transaction par mois par âge
transaction_client_YearMonth_age = transaction_client_YearMonth_session_id.groupby(by =["YearMonth", "age"]).agg({"frequence_achat_mensuel": "sum"})
transaction_client_YearMonth_age = transaction_client_YearMonth_age.reset_index()
transaction_client_YearMonth_age
# Out:
#     YearMonth  age  frequence_achat_mensuel
# 0     2021_03   18                      328
# 1     2021_03   19                      119
# 2     2021_03   20                       82
# 3     2021_03   21                       90
# 4     2021_03   22                      111
# ..        ...  ...                      ...
# 831   2022_02   89                       18
# 832   2022_02   90                       10
# 833   2022_02   91                        3
# 834   2022_02   92                       11
# 835   2022_02   93                        8
#
# [836 rows x 3 columns]

# %%
#Nombre moyen de transaction par mois en fonction de l'âge 
transaction_client_Year = transaction_client_YearMonth_age.groupby(by =["age"]).agg({"frequence_achat_mensuel": "mean"})
transaction_client_Year = transaction_client_Year.reset_index()
transaction_client_Year
# Out:
#     age  frequence_achat_mensuel
# 0    18               357.363636
# 1    19               107.454545
# 2    20               109.000000
# 3    21               101.181818
# 4    22               101.636364
# ..  ...                      ...
# 71   89                 9.818182
# 72   90                 8.454545
# 73   91                 4.000000
# 74   92                 6.272727
# 75   93                 5.636364
#
# [76 rows x 2 columns]

# %%
x = transaction_client_Year["age"]
y = transaction_client_Year["frequence_achat_mensuel"]

plt.figure(figsize = (20, 12))
ax = plt.axes()
ax = ax.set(xlabel = "Âge des clients", ylabel = "Fréquence d'achat par mois" )
plt.plot(fontsize = 25)
plt.title(" Corrélation entre l'âge des clients et la fréquence d'achat", color = "blue")
plt.plot(x, y, color = "pink", marker = "o")
plt.savefig("Nombre moyen de transaction")

# %%
print(st.pearsonr(transaction_client_Year["age"],transaction_client_Year["frequence_achat_mensuel"])[0])
# Out:
# -0.5975335096541198

# %% [raw]
# Le coéfficient de Pearson est de -0.59 (corrélation négative) signifiant que lorsque l'âge du client augmente, la fréquence d'achat diminue.Les clients les plus âgés achètent peu souvent
# Il y a donc corrélation entre l'âge des clients et la fréquence d'achat

# %% [raw]
# 1.	Y a-t-il une corrélation entre le sexe des clients et les catégories de produits achetés ?
#
#
# 2.	Y a-t-il une corrélation entre l'âge des clients et le montant total des achats
#     Le coéfficient de Pearson est de -0.19 donc il bien une corrélation entre l'âge des clients et le montant total de leurs achats
#
# 3.  Y a-t-il une corrélation entre l'âge des clients et les catégories de produits achetés?
# eta^2 = 0.11 donc il y a bien une  corrélation entre sexe des clients et la catégorie des produits
#
# 4. Y a-t-il une corrélation entre l'âge des clients et la fréquence d'achat?
#     Le coéfficient de Pearson est de -0.57 on a donc une corrélation entre l'âge des clients et la fréquence d'achat

# %% [markdown]
# ### 5. Corrélation entre l'âge des clients et la taille du panier moyen (en nombre d’articles)

# %%
panier_moyen_YearMonth = transaction_client_YearMonth_session_id.groupby(by =["session_id", "YearMonth", "age"]).agg({"nb_articles_YearMonth": "sum"}) 
panier_moyen_YearMonth
# Out:
#                           nb_articles_YearMonth
# session_id YearMonth age
# s_1        2021_03   55                       1
# s_10       2021_03   52                       1
# s_100      2021_03   44                       2
# s_1000     2021_03   33                       4
# s_10000    2021_03   33                       3
# ...                                         ...
# s_9995     2021_03   48                       2
# s_9996     2021_03   18                       8
# s_9997     2021_03   64                       1
# s_9998     2021_03   32                       1
# s_9999     2021_03   38                       3
#
# [147085 rows x 1 columns]

# %%
panier_moyen_YearMonth = panier_moyen_YearMonth.groupby(by =["YearMonth", "age"]).agg({"nb_articles_YearMonth": "sum"})
panier_moyen_YearMonth
# Out:
#                nb_articles_YearMonth
# YearMonth age
# 2021_03   18                     596
#           19                     207
#           20                     136
#           21                     170
#           22                     187
# ...                              ...
# 2022_02   89                      29
#           90                      15
#           91                       9
#           92                      13
#           93                      11
#
# [836 rows x 1 columns]

# %%
panier_moyen_YearMonth = panier_moyen_YearMonth.groupby(by =["age"]).agg({"nb_articles_YearMonth": "mean"})
panier_moyen_YearMonth = panier_moyen_YearMonth.reset_index()
panier_moyen_YearMonth
# Out:
#     age  nb_articles_YearMonth
# 0    18             633.636364
# 1    19             186.272727
# 2    20             191.363636
# 3    21             176.454545
# 4    22             187.181818
# ..  ...                    ...
# 71   89              13.818182
# 72   90              12.818182
# 73   91               7.090909
# 74   92              10.090909
# 75   93               7.636364
#
# [76 rows x 2 columns]

# %%
x = panier_moyen_YearMonth["age"]
y = panier_moyen_YearMonth["nb_articles_YearMonth"]

plt.figure(figsize = (20, 12))
ax = plt.axes()
ax = ax.set(xlabel = "Âge des clients", ylabel = "Nombre d'article par transaction par an" )
plt.plot(fontsize = 40)
plt.title(" Corrélation entre l'âge des clients et la taille du panier moyen", color = "blue")
plt.plot(x, y, color = "pink", marker = "o")
plt.savefig(" Nombre d'articles par transaction")

# %%
print(st.pearsonr(panier_moyen_YearMonth["age"],panier_moyen_YearMonth["nb_articles_YearMonth"])[0])
# Out:
# -0.57286915278624

# %% [raw]
# Le coéfficient de Pearson est de -0.57 (corrélation négative) signifiant que lorsque l'âge du client augmente, le nombre d'articles achetés diminue.Les clients les plus âgés achètent peu de produits
# Il y a donc corrélation entre l'âge des clients et le nombre d'articles achetés
